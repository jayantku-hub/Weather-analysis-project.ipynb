# %% [markdown]
# <a href="https://colab.research.google.com/github/jayantku-hub/Weather-analysis-project.ipynb/blob/main/Weather_analysis_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset

# %%
data = pd.read_csv('/content/file.csv')

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# # cleasnojng the data set via removing the index
# # (inplace=True) means : programme perform the permanent operation to the DataFrame
# data.drop(columns=  'index',inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
data.head(
)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data.value_counts()
# Out:
# Date/Time       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 9/9/2012 16:00   17.9    8.4              54         22               48.3           100.71     Mainly Clear     1
# 9/9/2012 15:00   17.6    8.9              57         17               48.3           100.67     Mostly Cloudy    1
# 9/9/2012 14:00   18.1    8.4              53         19               48.3           100.67     Mostly Cloudy    1
# 9/9/2012 13:00   17.3    8.6              57         11               48.3           100.68     Mainly Clear     1
# 9/9/2012 12:00   17.3    8.9              58         22               48.3           100.65     Mainly Clear     1
#                                                                                                                 ..
# 1/1/2012 13:00   0.2    -1.7              87         13               4.8            100.58     Fog              1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# **Q1 . find all the unique 'windspeed' values in the data.**
# ```
# `# This is formatted as code`
# ```

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data['Wind Speed_km/h'].nunique()
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# **Q2. Find the no of times when the weather is actually clear.**

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=data)
# Out:
# https://docs.google.com/spreadsheets/d/1tTRXyL3gStf5XQnmV6uFwKPIX2jamB3CDJ3QaeYFd8k/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1tTRXyL3gStf5XQnmV6uFwKPIX2jamB3CDJ3QaeYFd8k/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
data.Weather.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# filtering comand

# %%
data[data.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#grouby command

data.groupby('Weather').get_group('Clear')

# %% [markdown]
# **Q3. find the no of times where the windspped exactly 4km/hr**

# %%
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# **Q4 find the null value in the data**

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# **Q5 Rename the column Weather to Weather Condition**

# %%
data.rename(columns = {'Weather' : 'Weather Condition '})
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# **Q6 What is mean of the Visibility_km**

# %%
data.Visibility_km.mean()
# Out:
# np.float64(27.664446721311478)

# %% [markdown]
# **Q 7 What is the standard deviation of 'Pressure' in this data?**

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# **Q8. What is the variance of 'Relative Humidity' in this data? **

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# **Q9. What all instance when 'Snow' was recorded.**

# %%
import pandas as pd
data = pd.read_csv('/content/file.csv')
data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)
data[data['Weather Condition'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# **Q . 10 Find all the instance where fog is reccorded.**

# %%
data['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
#filtering

data[data['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
#Str.contains :

data[data['Weather Condition'].str.contains('Snow')].tail(50)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012 16:00    -4.5              -6.2         88               37
# 8681  12/27/2012 17:00    -4.2              -5.9         88               32
# 8682  12/27/2012 18:00    -4.0              -5.7         88               28
# 8683  12/27/2012 19:00    -3.9              -5.6         88               26
# 8684  12/27/2012 20:00    -3.7              -5.3         89               37
# 8685  12/27/2012 21:00    -3.7              -4.8         92               24
# 8686  12/27/2012 22:00    -3.8              -4.6         94               20
# 8687  12/27/2012 23:00    -4.0              -5.6         89               24
# 8688   12/28/2012 0:00    -4.2              -5.7         89               19
# 8689   12/28/2012 1:00    -4.4              -6.6         85               15
# 8690   12/28/2012 2:00    -4.3              -6.3         86               11
# ...

# %% [markdown]
# Q 10. Find all the instance when wind speed is above 24' and visiblity is 25'.

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# Q 11. what is the mean value of each value of each column againt each 'weather condition'?

# %%
data.groupby('Weather Condition').mean(numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# Q 12. What is maximum value of each value of each column against each 'weather Condition'?

# %%
data.groupby('Weather Condition').max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %% [markdown]
# Q.13 Show the Record where weather condition is Fog.

# %%
data[data['Weather Condition'] == 'Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %% [markdown]
# Q. 14 Find all instance when 'Weather is clear' or visiblity is above 40'.

# %%
data[(data['Weather Condition'] == 'Clear' ) |  (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %% [markdown]
# 15 . Find all instance when :
#
# a . 'Weather is clear' and 'Relative Hu,idity' is greater than 50'
#
# or
#
# b . 'Visiblity is above 40'

# %% [markdown]
# # Task
# Create a GitHub project that includes a Python script for weather data analysis, a `README.md` file, and a `requirements.txt` file. The analysis script should consolidate all the data processing and querying steps performed in the notebook on the `file.csv` dataset, including:
# 1. Identifying unique wind speed values.
# 2. Counting instances of 'Clear' weather.
# 3. Filtering data for specific wind speeds (e.g., 4 km/h).
# 4. Checking for null values.
# 5. Renaming the 'Weather' column to 'Weather Condition'.
# 6. Calculating the mean visibility.
# 7. Calculating the standard deviation of pressure.
# 8. Calculating the variance of relative humidity.
# 9. Identifying all instances where 'Snow' was recorded.
# 10. Identifying all instances where 'Fog' was recorded.
# 11. Filtering for records where wind speed is greater than 24 km/h AND visibility is 25 km.
# 12. Calculating the mean of each numerical column grouped by 'Weather Condition'.
# 13. Calculating the maximum of each numerical column grouped by 'Weather Condition'.
# 14. Filtering for records where 'Weather Condition' is 'Clear' OR 'Visibility_km' is greater than 40.
# 15. Filtering for records where ('Weather Condition' is 'Clear' AND 'Rel Hum_%' is greater than 50) OR 'Visibility_km' is greater than 40.
#
# The `README.md` should describe the project, dataset, analysis, how to run the code, and key findings. The `requirements.txt` should list all necessary Python libraries.

# %% [markdown]
# ## Summarize Analysis
#
# ### Subtask:
# Review the existing notebook to understand the weather dataset, the specific questions asked, and the analysis performed. This includes data loading, exploration, filtering, column renaming, and statistical calculations.

# %% [markdown]
# ### Summary of Analysis Performed
#
# 1.  **Data Loading and Initial Exploration:**
#     *   The `file.csv` dataset was loaded into a pandas DataFrame named `data` using `pd.read_csv()`. (cell `ZMtczE7DCUIN`)
#     *   Initial exploration included viewing the first few rows (`data.head()` in cell `qMzyozH5Cpax`, `KJ4j0KY-GXRb`), checking data types and non-null counts (`data.info()` in cell `7cblVCqcEYXV`, `GZOSdZBjKpQU`), and generating descriptive statistics (`data.describe()` in cell `27dmIa6_E2-n`).
#     *   The shape of the DataFrame was checked (`data.shape` in cell `l7a8n5mKGd4x`), and unique values for the 'Weather' column were identified (`data['Weather'].unique()` in cell `KXMB7dUkHPqY`).
#     *   The number of unique values in each column was determined using `data.nunique()` (cell `epBdBv9CH-id`).
#
# 2.  **Specific Questions and Solutions (Q1-Q15):**
#     *   **Q1 (Unique Wind Speed Values):** Addressed by `data['Wind Speed_km/h'].nunique()` and `data['Wind Speed_km/h'].unique()` (cell `7njzYfOHLHMI`).
#     *   **Q2 (Times Weather is Clear):** Addressed by `data.Weather.value_counts()` (cell `uPxsL2DfNzMC`) and filtering `data[data.Weather == 'Clear']` (cell `9kJGeIu2OdJy`). Also used `data.groupby('Weather').get_group('Clear')` (cell `xA-nSGSPO_vS`).
#     *   **Q3 (Wind Speed Exactly 4 km/hr):** Addressed by filtering `data[data['Wind Speed_km/h'] == 4]` (cell `E_xZdBu8PEF_`).
#     *   **Q4 (Null Values):** Addressed by `data.isnull().sum()` (cell `EIz-X0XeQHg4`) and `data.notnull().sum()` (cell `v8ozfxFgQdw1`).
#     *   **Q5 (Rename 'Weather' to 'Weather Condition'):** Addressed by `data.rename(columns = {'Weather' : 'Weather Condition '})` (cell `on6TvA84RBM-`) and then confirmed with `inplace=True` in `data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)` (cell `AA1Y8D7oRe3Q`).
#     *   **Q6 (Mean of Visibility_km):** Addressed by `data.Visibility_km.mean()` (cell `sF5QCIkRSeCX`).
#     *   **Q7 (Standard Deviation of 'Pressure'):** Addressed by `data.Press_kPa.std()` (cell `QnsIcjtKSsbq`).
#     *   **Q8 (Variance of 'Relative Humidity'):** Addressed by `data['Rel Hum_%'].var()` (cell `ODgYBtO-UHBX`).
#     *   **Q9 (Instances of 'Snow'):** Addressed by `data[data['Weather Condition'].str.contains('Snow')]` (cell `xHfhjtWIVJK0`). The column was already renamed in this context.
#     *   **Q10 (Instances of 'Fog'):** Addressed by `data['Weather Condition'].value_counts()` (cell `G_Azk9ZHRKsf`) and filtering `data[data['Weather Condition'] == 'Fog']` (cell `uoeLRHfAR2yb`).
#     *   **Q11 (Mean values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').mean(numeric_only=True)` (cell `HT0ENLqF5UHf`).
#     *   **Q12 (Maximum values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').max()` (cell `8iAOh-hY6qCO`).
#     *   **Q13 (Records where weather condition is Fog):** Addressed by `data[data['Weather Condition'] == 'Fog']` (cell `-wtmheSa7MVx`).
#     *   **Q14 (Weather is Clear OR Visibility is above 40):** Addressed by `data[(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)]` (cell `e9uRGbYb8DiF`).
#
# 3.  **Data Manipulation Techniques:**
#     *   **Filtering Rows:** extensively used with boolean indexing (e.g., `data[data.Weather == 'Clear']`, `data[data['Wind Speed_km/h'] == 4]`).
#     *   **Selecting Columns:** used `data['ColumnName']` to select specific columns.
#     *   **Renaming Columns:** `data.rename(columns={'old_name': 'new_name'}, inplace=True)` was used to change 'Weather' to 'Weather Condition'.
#     *   **Checking Null Values:** `data.isnull().sum()` and `data.notnull().sum()`.
#     *   **Statistical Calculations:** `mean()`, `std()`, `var()`, `nunique()`, `count()`, `value_counts()`.
#     *   **String Operations:** `str.contains()` was used for pattern matching in the 'Weather Condition' column.
#
# 4.  **Column Renaming Consistency:**
#     *   The 'Weather' column was permanently renamed to 'Weather Condition' using `inplace=True` in cell `AA1Y8D7oRe3Q`. Subsequent analyses correctly used the new column name (e.g., in Q9, Q10, Q11, Q12, Q13, Q14).
#
# 5.  **Grouping Data and Aggregations:**
#     *   The `groupby()` method was used to group data by 'Weather Condition'.
#     *   Aggregations such as `mean(numeric_only=True)` and `max()` were applied to the grouped data to calculate average and maximum values for numerical columns, respectively, for each weather condition.
#
# 6.  **Filtering Conditions with Logical Operators:**
#     *   Logical OR (`|`) was explicitly used in Q14 to combine filtering criteria: `(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)`.

# %% [markdown]
# ### Summary of Analysis Performed
#
# 1.  **Data Loading and Initial Exploration:**
#     *   The `file.csv` dataset was loaded into a pandas DataFrame named `data` using `pd.read_csv()`. (cell `ZMtczE7DCUIN`)
#     *   Initial exploration included viewing the first few rows (`data.head()` in cell `qMzyozH5Cpax`, `KJ4j0KY-GXRb`), checking data types and non-null counts (`data.info()` in cell `7cblVCqcEYXV`, `GZOSdZBjKpQU`), and generating descriptive statistics (`data.describe()` in cell `27dmIa6_E2-n`).
#     *   The shape of the DataFrame was checked (`data.shape` in cell `l7a8n5mKGd4x`), and unique values for the 'Weather' column were identified (`data['Weather'].unique()` in cell `KXMB7dUkHPqY`).
#     *   The number of unique values in each column was determined using `data.nunique()` (cell `epBdBv9CH-id`).
#
# 2.  **Specific Questions and Solutions (Q1-Q15):**
#     *   **Q1 (Unique Wind Speed Values):** Addressed by `data['Wind Speed_km/h'].nunique()` and `data['Wind Speed_km/h'].unique()` (cell `7njzYfOHLHMI`).
#     *   **Q2 (Times Weather is Clear):** Addressed by `data.Weather.value_counts()` (cell `uPxsL2DfNzMC`) and filtering `data[data.Weather == 'Clear']` (cell `9kJGeIu2OdJy`). Also used `data.groupby('Weather').get_group('Clear')` (cell `xA-nSGSPO_vS`).
#     *   **Q3 (Wind Speed Exactly 4 km/hr):** Addressed by filtering `data[data['Wind Speed_km/h'] == 4]` (cell `E_xZdBu8PEF_`).
#     *   **Q4 (Null Values):** Addressed by `data.isnull().sum()` (cell `EIz-X0XeQHg4`) and `data.notnull().sum()` (cell `v8ozfxFgQdw1`).
#     *   **Q5 (Rename 'Weather' to 'Weather Condition'):** Addressed by `data.rename(columns = {'Weather' : 'Weather Condition '})` (cell `on6TvA84RBM-`) and then confirmed with `inplace=True` in `data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)` (cell `AA1Y8D7oRe3Q`).
#     *   **Q6 (Mean of Visibility_km):** Addressed by `data.Visibility_km.mean()` (cell `sF5QCIkRSeCX`).
#     *   **Q7 (Standard Deviation of 'Pressure'):** Addressed by `data.Press_kPa.std()` (cell `QnsIcjtKSsbq`).
#     *   **Q8 (Variance of 'Relative Humidity'):** Addressed by `data['Rel Hum_%'].var()` (cell `ODgYBtO-UHBX`).
#     *   **Q9 (Instances of 'Snow'):** Addressed by `data[data['Weather Condition'].str.contains('Snow')]` (cell `xHfhjtWIVJK0`). The column was already renamed in this context.
#     *   **Q10 (Instances of 'Fog'):** Addressed by `data['Weather Condition'].value_counts()` (cell `G_Azk9ZHRKsf`) and filtering `data[data['Weather Condition'] == 'Fog']` (cell `uoeLRHfAR2yb`).
#     *   **Q11 (Mean values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').mean(numeric_only=True)` (cell `HT0ENLqF5UHf`).
#     *   **Q12 (Maximum values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').max()` (cell `8iAOh-hY6qCO`).
#     *   **Q13 (Records where weather condition is Fog):** Addressed by `data[data['Weather Condition'] == 'Fog']` (cell `-wtmheSa7MVx`).
#     *   **Q14 (Weather is Clear OR Visibility is above 40):** Addressed by `data[(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)]` (cell `e9uRGbYb8DiF`).
#
# 3.  **Data Manipulation Techniques:**
#     *   **Filtering Rows:** extensively used with boolean indexing (e.g., `data[data.Weather == 'Clear']`, `data[data['Wind Speed_km/h'] == 4]`).
#     *   **Selecting Columns:** used `data['ColumnName']` to select specific columns.
#     *   **Renaming Columns:** `data.rename(columns={'old_name': 'new_name'}, inplace=True)` was used to change 'Weather' to 'Weather Condition'.
#     *   **Checking Null Values:** `data.isnull().sum()` and `data.notnull().sum()`.
#     *   **Statistical Calculations:** `mean()`, `std()`, `var()`, `nunique()`, `count()`, `value_counts()`.
#     *   **String Operations:** `str.contains()` was used for pattern matching in the 'Weather Condition' column.
#
# 4.  **Column Renaming Consistency:**
#     *   The 'Weather' column was permanently renamed to 'Weather Condition' using `inplace=True` in cell `AA1Y8D7oRe3Q`. Subsequent analyses correctly used the new column name (e.g., in Q9, Q10, Q11, Q12, Q13, Q14).
#
# 5.  **Grouping Data and Aggregations:**
#     *   The `groupby()` method was used to group data by 'Weather Condition'.
#     *   Aggregations such as `mean(numeric_only=True)` and `max()` were applied to the grouped data to calculate average and maximum values for numerical columns, respectively, for each weather condition.
#
# 6.  **Filtering Conditions with Logical Operators:**
#     *   Logical OR (`|`) was explicitly used in Q14 to combine filtering criteria: `(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)`.

# %% [markdown]
# ### Summary of Analysis Performed
#
# 1.  **Data Loading and Initial Exploration:**
#     *   The `file.csv` dataset was loaded into a pandas DataFrame named `data` using `pd.read_csv()`. (cell `ZMtczE7DCUIN`)
#     *   Initial exploration included viewing the first few rows (`data.head()` in cell `qMzyozH5Cpax`, `KJ4j0KY-GXRb`), checking data types and non-null counts (`data.info()` in cell `7cblVCqcEYXV`, `GZOSdZBjKpQU`), and generating descriptive statistics (`data.describe()` in cell `27dmIa6_E2-n`).
#     *   The shape of the DataFrame was checked (`data.shape` in cell `l7a8n5mKGd4x`), and unique values for the 'Weather' column were identified (`data['Weather'].unique()` in cell `KXMB7dUkHPqY`).
#     *   The number of unique values in each column was determined using `data.nunique()` (cell `epBdBv9CH-id`).
#
# 2.  **Specific Questions and Solutions (Q1-Q15):**
#     *   **Q1 (Unique Wind Speed Values):** Addressed by `data['Wind Speed_km/h'].nunique()` and `data['Wind Speed_km/h'].unique()` (cell `7njzYfOHLHMI`).
#     *   **Q2 (Times Weather is Clear):** Addressed by `data.Weather.value_counts()` (cell `uPxsL2DfNzMC`) and filtering `data[data.Weather == 'Clear']` (cell `9kJGeIu2OdJy`). Also used `data.groupby('Weather').get_group('Clear')` (cell `xA-nSGSPO_vS`).
#     *   **Q3 (Wind Speed Exactly 4 km/hr):** Addressed by filtering `data[data['Wind Speed_km/h'] == 4]` (cell `E_xZdBu8PEF_`).
#     *   **Q4 (Null Values):** Addressed by `data.isnull().sum()` (cell `EIz-X0XeQHg4`) and `data.notnull().sum()` (cell `v8ozfxFgQdw1`).
#     *   **Q5 (Rename 'Weather' to 'Weather Condition'):** Addressed by `data.rename(columns = {'Weather' : 'Weather Condition '})` (cell `on6TvA84RBM-`) and then confirmed with `inplace=True` in `data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)` (cell `AA1Y8D7oRe3Q`).
#     *   **Q6 (Mean of Visibility_km):** Addressed by `data.Visibility_km.mean()` (cell `sF5QCIkRSeCX`).
#     *   **Q7 (Standard Deviation of 'Pressure'):** Addressed by `data.Press_kPa.std()` (cell `QnsIcjtKSsbq`).
#     *   **Q8 (Variance of 'Relative Humidity'):** Addressed by `data['Rel Hum_%'].var()` (cell `ODgYBtO-UHBX`).
#     *   **Q9 (Instances of 'Snow'):** Addressed by `data[data['Weather Condition'].str.contains('Snow')]` (cell `xHfhjtWIVJK0`). The column was already renamed in this context.
#     *   **Q10 (Instances of 'Fog'):** Addressed by `data['Weather Condition'].value_counts()` (cell `G_Azk9ZHRKsf`) and filtering `data[data['Weather Condition'] == 'Fog']` (cell `uoeLRHfAR2yb`).
#     *   **Q11 (Mean values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').mean(numeric_only=True)` (cell `HT0ENLqF5UHf`).
#     *   **Q12 (Maximum values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').max()` (cell `8iAOh-hY6qCO`).
#     *   **Q13 (Records where weather condition is Fog):** Addressed by `data[data['Weather Condition'] == 'Fog']` (cell `-wtmheSa7MVx`).
#     *   **Q14 (Weather is Clear OR Visibility is above 40):** Addressed by `data[(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)]` (cell `e9uRGbYb8DiF`).
#
# 3.  **Data Manipulation Techniques:**
#     *   **Filtering Rows:** extensively used with boolean indexing (e.g., `data[data.Weather == 'Clear']`, `data[data['Wind Speed_km/h'] == 4]`).
#     *   **Selecting Columns:** used `data['ColumnName']` to select specific columns.
#     *   **Renaming Columns:** `data.rename(columns={'old_name': 'new_name'}, inplace=True)` was used to change 'Weather' to 'Weather Condition'.
#     *   **Checking Null Values:** `data.isnull().sum()` and `data.notnull().sum()`.
#     *   **Statistical Calculations:** `mean()`, `std()`, `var()`, `nunique()`, `count()`, `value_counts()`.
#     *   **String Operations:** `str.contains()` was used for pattern matching in the 'Weather Condition' column.
#
# 4.  **Column Renaming Consistency:**
#     *   The 'Weather' column was permanently renamed to 'Weather Condition' using `inplace=True` in cell `AA1Y8D7oRe3Q`. Subsequent analyses correctly used the new column name (e.g., in Q9, Q10, Q11, Q12, Q13, Q14).
#
# 5.  **Grouping Data and Aggregations:**
#     *   The `groupby()` method was used to group data by 'Weather Condition'.
#     *   Aggregations such as `mean(numeric_only=True)` and `max()` were applied to the grouped data to calculate average and maximum values for numerical columns, respectively, for each weather condition.
#
# 6.  **Filtering Conditions with Logical Operators:**
#     *   Logical OR (`|`) was explicitly used in Q14 to combine filtering criteria: `(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)`.

# %% [markdown]
# ### Summary of Analysis Performed
#
# 1.  **Data Loading and Initial Exploration:**
#     *   The `file.csv` dataset was loaded into a pandas DataFrame named `data` using `pd.read_csv()`. (cell `ZMtczE7DCUIN`)
#     *   Initial exploration included viewing the first few rows (`data.head()` in cell `qMzyozH5Cpax`, `KJ4j0KY-GXRb`), checking data types and non-null counts (`data.info()` in cell `7cblVCqcEYXV`, `GZOSdZBjKpQU`), and generating descriptive statistics (`data.describe()` in cell `27dmIa6_E2-n`).
#     *   The shape of the DataFrame was checked (`data.shape` in cell `l7a8n5mKGd4x`), and unique values for the 'Weather' column were identified (`data['Weather'].unique()` in cell `KXMB7dUkHPqY`).
#     *   The number of unique values in each column was determined using `data.nunique()` (cell `epBdBv9CH-id`).
#
# 2.  **Specific Questions and Solutions (Q1-Q15):**
#     *   **Q1 (Unique Wind Speed Values):** Addressed by `data['Wind Speed_km/h'].nunique()` and `data['Wind Speed_km/h'].unique()` (cell `7njzYfOHLHMI`).
#     *   **Q2 (Times Weather is Clear):** Addressed by `data.Weather.value_counts()` (cell `uPxsL2DfNzMC`) and filtering `data[data.Weather == 'Clear']` (cell `9kJGeIu2OdJy`). Also used `data.groupby('Weather').get_group('Clear')` (cell `xA-nSGSPO_vS`).
#     *   **Q3 (Wind Speed Exactly 4 km/hr):** Addressed by filtering `data[data['Wind Speed_km/h'] == 4]` (cell `E_xZdBu8PEF_`).
#     *   **Q4 (Null Values):** Addressed by `data.isnull().sum()` (cell `EIz-X0XeQHg4`) and `data.notnull().sum()` (cell `v8ozfxFgQdw1`).
#     *   **Q5 (Rename 'Weather' to 'Weather Condition'):** Addressed by `data.rename(columns = {'Weather' : 'Weather Condition '})` (cell `on6TvA84RBM-`) and then confirmed with `inplace=True` in `data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)` (cell `AA1Y8D7oRe3Q`).
#     *   **Q6 (Mean of Visibility_km):** Addressed by `data.Visibility_km.mean()` (cell `sF5QCIkRSeCX`).
#     *   **Q7 (Standard Deviation of 'Pressure'):** Addressed by `data.Press_kPa.std()` (cell `QnsIcjtKSsbq`).
#     *   **Q8 (Variance of 'Relative Humidity'):** Addressed by `data['Rel Hum_%'].var()` (cell `ODgYBtO-UHBX`).
#     *   **Q9 (Instances of 'Snow'):** Addressed by `data[data['Weather Condition'].str.contains('Snow')]` (cell `xHfhjtWIVJK0`). The column was already renamed in this context.
#     *   **Q10 (Instances of 'Fog'):** Addressed by `data['Weather Condition'].value_counts()` (cell `G_Azk9ZHRKsf`) and filtering `data[data['Weather Condition'] == 'Fog']` (cell `uoeLRHfAR2yb`).
#     *   **Q11 (Mean values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').mean(numeric_only=True)` (cell `HT0ENLqF5UHf`).
#     *   **Q12 (Maximum values grouped by 'Weather Condition'):** Addressed by `data.groupby('Weather Condition').max()` (cell `8iAOh-hY6qCO`).
#     *   **Q13 (Records where weather condition is Fog):** Addressed by `data[data['Weather Condition'] == 'Fog']` (cell `-wtmheSa7MVx`).
#     *   **Q14 (Weather is Clear OR Visibility is above 40):** Addressed by `data[(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)]` (cell `e9uRGbYb8DiF`).
#
# 3.  **Data Manipulation Techniques:**
#     *   **Filtering Rows:** extensively used with boolean indexing (e.g., `data[data.Weather == 'Clear']`, `data[data['Wind Speed_km/h'] == 4]`).
#     *   **Selecting Columns:** used `data['ColumnName']` to select specific columns.
#     *   **Renaming Columns:** `data.rename(columns={'old_name': 'new_name'}, inplace=True)` was used to change 'Weather' to 'Weather Condition'.
#     *   **Checking Null Values:** `data.isnull().sum()` and `data.notnull().sum()`.
#     *   **Statistical Calculations:** `mean()`, `std()`, `var()`, `nunique()`, `count()`, `value_counts()`.
#     *   **String Operations:** `str.contains()` was used for pattern matching in the 'Weather Condition' column.
#
# 4.  **Column Renaming Consistency:**
#     *   The 'Weather' column was permanently renamed to 'Weather Condition' using `inplace=True` in cell `AA1Y8D7oRe3Q`. Subsequent analyses correctly used the new column name (e.g., in Q9, Q10, Q11, Q12, Q13, Q14).
#
# 5.  **Grouping Data and Aggregations:**
#     *   The `groupby()` method was used to group data by 'Weather Condition'.
#     *   Aggregations such as `mean(numeric_only=True)` and `max()` were applied to the grouped data to calculate average and maximum values for numerical columns, respectively, for each weather condition.
#
# 6.  **Filtering Conditions with Logical Operators:**
#     *   Logical OR (`|`) was explicitly used in Q14 to combine filtering criteria: `(data['Weather Condition'] == 'Clear' ) | (data['Visibility_km'] > 40)`.

# %% [markdown]
# ## Prepare Code for GitHub Project
#
# ### Subtask:
# Consolidate the data analysis steps from the notebook into a structured Python script (e.g., weather_analysis.py). This script will include loading the data, performing the key queries (unique wind speeds, clear weather counts, specific wind speed filters, null checks, column renaming, mean/std/var calculations, snow and fog instances, combined wind speed/visibility filter, grouped means, grouped max).

# %% [markdown]
# **Reasoning**:
# I will provide the content for the `weather_analysis.py` file, encapsulating all the requested data loading and analysis functions, along with a `main` function and the standard Python entry point.

# %%
import pandas as pd

def load_data(file_path):
    """
    Loads the CSV data into a pandas DataFrame and renames the 'Weather' column.
    """
    df = pd.read_csv(file_path)
    df.rename(columns={'Weather': 'Weather Condition'}, inplace=True)
    return df

def get_unique_wind_speeds(df):
    """
    Returns unique 'Wind Speed_km/h' values.
    """
    return df['Wind Speed_km/h'].unique()

def count_clear_weather(df):
    """
    Returns the count of 'Clear' weather conditions.
    """
    return df[df['Weather Condition'] == 'Clear'].shape[0]

def filter_wind_speed_4kmh(df):
    """
    Filters records where 'Wind Speed_km/h' is exactly 4 km/h.
    """
    return df[df['Wind Speed_km/h'] == 4]

def check_null_values(df):
    """
    Returns the sum of null values per column.
    """
    return df.isnull().sum()

def calculate_mean_visibility(df):
    """
    Returns the mean of 'Visibility_km'.
    """
    return df['Visibility_km'].mean()

def calculate_std_pressure(df):
    """
    Returns the standard deviation of 'Press_kPa'.
    """
    return df['Press_kPa'].std()

def calculate_var_rel_hum(df):
    """
    Returns the variance of 'Rel Hum_%'.
    """
    return df['Rel Hum_%'].var()

def get_snow_instances(df):
    """
    Filters records where 'Weather Condition' contains 'Snow'.
    """
    return df[df['Weather Condition'].str.contains('Snow')]

def get_fog_instances(df):
    """
    Filters records where 'Weather Condition' is 'Fog'.
    """
    return df[df['Weather Condition'] == 'Fog']

def filter_wind_speed_visibility(df):
    """
    Filters records where 'Wind Speed_km/h' > 24 AND 'Visibility_km' == 25.
    """
    return df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km'] == 25)]

def get_grouped_mean_by_weather(df):
    """
    Returns the mean of numerical columns grouped by 'Weather Condition'.
    """
    return df.groupby('Weather Condition').mean(numeric_only=True)

def get_grouped_max_by_weather(df):
    """
    Returns the maximum of numerical columns grouped by 'Weather Condition'.
    """
    return df.groupby('Weather Condition').max()

def filter_clear_or_high_visibility(df):
    """
    Filters records where 'Weather Condition' is 'Clear' OR 'Visibility_km' > 40.
    """
    return df[(df['Weather Condition'] == 'Clear') | (df['Visibility_km'] > 40)]

def filter_clear_and_humid_or_high_visibility(df):
    """
    Filters records where ('Weather Condition' is 'Clear' AND 'Rel Hum_%' > 50) OR 'Visibility_km' > 40.
    """
    return df[((df['Weather Condition'] == 'Clear') & (df['Rel Hum_%'] > 50)) | (df['Visibility_km'] > 40)]

def main():
    file_path = '/content/file.csv' # Assuming the file is in the same directory or accessible path
    weather_data = load_data(file_path)

    print("\n--- Unique Wind Speed Values ---")
    print(get_unique_wind_speeds(weather_data))

    print("\n--- Count of Clear Weather Conditions ---")
    print(count_clear_weather(weather_data))

    print("\n--- Records with Wind Speed exactly 4 km/h ---")
    print(filter_wind_speed_4kmh(weather_data).head())

    print("\n--- Null Values per Column ---")
    print(check_null_values(weather_data))

    print("\n--- Mean Visibility (km) ---")
    print(calculate_mean_visibility(weather_data))

    print("\n--- Standard Deviation of Pressure (kPa) ---")
    print(calculate_std_pressure(weather_data))

    print("\n--- Variance of Relative Humidity (%) ---")
    print(calculate_var_rel_hum(weather_data))

    print("\n--- Records with Snow in Weather Condition ---")
    print(get_snow_instances(weather_data).head())

    print("\n--- Records with Fog Weather Condition ---")
    print(get_fog_instances(weather_data).head())

    print("\n--- Records with Wind Speed > 24 km/h AND Visibility == 25 km ---")
    print(filter_wind_speed_visibility(weather_data).head())

    print("\n--- Mean of Numerical Columns Grouped by Weather Condition ---")
    print(get_grouped_mean_by_weather(weather_data).head())

    print("\n--- Maximum of Numerical Columns Grouped by Weather Condition ---")
    print(get_grouped_max_by_weather(weather_data).head())

    print("\n--- Records with Clear Weather OR Visibility > 40 km ---")
    print(filter_clear_or_high_visibility(weather_data).head())

    print("\n--- Records with (Clear Weather AND Relative Humidity > 50) OR Visibility > 40 km ---")
    print(filter_clear_and_humid_or_high_visibility(weather_data).head())

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2419663170.py in <cell line: 0>()
#     140
#     141 if __name__ == '__main__':
# --> 142     main()
#
# /tmp/ipython-input-2419663170.py in main()
#      95 def main():
#      96     file_path = '/content/file.csv' # Assuming the file is in the same directory or accessible path
# ---> 97     weather_data = load_data(file_path)
#      98
#      99     print("\n--- Unique Wind Speed Values ---")
#
# /tmp/ipython-input-2419663170.py in load_data(file_path)
#       5     Loads the CSV data into a pandas DataFrame and renames the 'Weather' column.
#       6     """
# ----> 7     df = pd.read_csv(file_path)
#       8     df.rename(columns={'Weather': 'Weather Condition'}, inplace=True)
#       9     return df
#
# ...

# %% [markdown]
# **Reasoning**:
# The previous code failed with a `FileNotFoundError` because the specified file path `/content/file.csv` is specific to the Colab environment and was not found when the script was executed. To make the script portable for a GitHub project, I will change the file path to `file.csv`, assuming the data file will be placed in the same directory as the script. I will also provide the full code again as instructed.

# %%
import pandas as pd

def load_data(file_path):
    """
    Loads the CSV data into a pandas DataFrame and renames the 'Weather' column.
    """
    df = pd.read_csv(file_path)
    df.rename(columns={'Weather': 'Weather Condition'}, inplace=True)
    return df

def get_unique_wind_speeds(df):
    """
    Returns unique 'Wind Speed_km/h' values.
    """
    return df['Wind Speed_km/h'].unique()

def count_clear_weather(df):
    """
    Returns the count of 'Clear' weather conditions.
    """
    return df[df['Weather Condition'] == 'Clear'].shape[0]

def filter_wind_speed_4kmh(df):
    """
    Filters records where 'Wind Speed_km/h' is exactly 4 km/h.
    """
    return df[df['Wind Speed_km/h'] == 4]

def check_null_values(df):
    """
    Returns the sum of null values per column.
    """
    return df.isnull().sum()

def calculate_mean_visibility(df):
    """
    Returns the mean of 'Visibility_km'.
    """
    return df['Visibility_km'].mean()

def calculate_std_pressure(df):
    """
    Returns the standard deviation of 'Press_kPa'.
    """
    return df['Press_kPa'].std()

def calculate_var_rel_hum(df):
    """
    Returns the variance of 'Rel Hum_%'.
    """
    return df['Rel Hum_%'].var()

def get_snow_instances(df):
    """
    Filters records where 'Weather Condition' contains 'Snow'.
    """
    return df[df['Weather Condition'].str.contains('Snow')]

def get_fog_instances(df):
    """
    Filters records where 'Weather Condition' is 'Fog'.
    """
    return df[df['Weather Condition'] == 'Fog']

def filter_wind_speed_visibility(df):
    """
    Filters records where 'Wind Speed_km/h' > 24 AND 'Visibility_km' == 25.
    """
    return df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km'] == 25)]

def get_grouped_mean_by_weather(df):
    """
    Returns the mean of numerical columns grouped by 'Weather Condition'.
    """
    return df.groupby('Weather Condition').mean(numeric_only=True)

def get_grouped_max_by_weather(df):
    """
    Returns the maximum of numerical columns grouped by 'Weather Condition'.
    """
    return df.groupby('Weather Condition').max()

def filter_clear_or_high_visibility(df):
    """
    Filters records where 'Weather Condition' is 'Clear' OR 'Visibility_km' > 40.
    """
    return df[(df['Weather Condition'] == 'Clear') | (df['Visibility_km'] > 40)]

def filter_clear_and_humid_or_high_visibility(df):
    """
    Filters records where ('Weather Condition' is 'Clear' AND 'Rel Hum_%' > 50) OR 'Visibility_km' > 40.
    """
    return df[((df['Weather Condition'] == 'Clear') & (df['Rel Hum_%'] > 50)) | (df['Visibility_km'] > 40)]

def main():
    file_path = 'file.csv' # Changed path for portability
    weather_data = load_data(file_path)

    print("\n--- Unique Wind Speed Values ---")
    print(get_unique_wind_speeds(weather_data))

    print("\n--- Count of Clear Weather Conditions ---")
    print(count_clear_weather(weather_data))

    print("\n--- Records with Wind Speed exactly 4 km/h ---")
    print(filter_wind_speed_4kmh(weather_data).head())

    print("\n--- Null Values per Column ---")
    print(check_null_values(weather_data))

    print("\n--- Mean Visibility (km) ---")
    print(calculate_mean_visibility(weather_data))

    print("\n--- Standard Deviation of Pressure (kPa) ---")
    print(calculate_std_pressure(weather_data))

    print("\n--- Variance of Relative Humidity (%) ---")
    print(calculate_var_rel_hum(weather_data))

    print("\n--- Records with Snow in Weather Condition ---")
    print(get_snow_instances(weather_data).head())

    print("\n--- Records with Fog Weather Condition ---")
    print(get_fog_instances(weather_data).head())

    print("\n--- Records with Wind Speed > 24 km/h AND Visibility == 25 km ---")
    print(filter_wind_speed_visibility(weather_data).head())

    print("\n--- Mean of Numerical Columns Grouped by Weather Condition ---")
    print(get_grouped_mean_by_weather(weather_data).head())

    print("\n--- Maximum of Numerical Columns Grouped by Weather Condition ---")
    print(get_grouped_max_by_weather(weather_data).head())

    print("\n--- Records with Clear Weather OR Visibility > 40 km ---")
    print(filter_clear_or_high_visibility(weather_data).head())

    print("\n--- Records with (Clear Weather AND Relative Humidity > 50) OR Visibility > 40 km ---")
    print(filter_clear_and_humid_or_high_visibility(weather_data).head())

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1226587302.py in <cell line: 0>()
#     140
#     141 if __name__ == '__main__':
# --> 142     main()
#
# /tmp/ipython-input-1226587302.py in main()
#      95 def main():
#      96     file_path = 'file.csv' # Changed path for portability
# ---> 97     weather_data = load_data(file_path)
#      98
#      99     print("\n--- Unique Wind Speed Values ---")
#
# /tmp/ipython-input-1226587302.py in load_data(file_path)
#       5     Loads the CSV data into a pandas DataFrame and renames the 'Weather' column.
#       6     """
# ----> 7     df = pd.read_csv(file_path)
#       8     df.rename(columns={'Weather': 'Weather Condition'}, inplace=True)
#       9     return df
#
# ...

# %% [markdown]
# **Reasoning**:
# The script correctly implements all the required data analysis steps for the GitHub project. The `FileNotFoundError` occurred because `file.csv` was not present in the execution environment where the code block was run, which is an environmental issue, not a code error for the intended GitHub project. The file path `file.csv` is appropriate for a portable script when the data file is placed in the same directory. I will provide the same code block again as it is structurally correct for the subtask, and then proceed to explain how to prepare the GitHub project files.

# %%
import pandas as pd

def load_data(file_path):
    """
    Loads the CSV data into a pandas DataFrame and renames the 'Weather' column.
    """
    df = pd.read_csv(file_path)
    df.rename(columns={'Weather': 'Weather Condition'}, inplace=True)
    return df

def get_unique_wind_speeds(df):
    """
    Returns unique 'Wind Speed_km/h' values.
    """
    return df['Wind Speed_km/h'].unique()

def count_clear_weather(df):
    """
    Returns the count of 'Clear' weather conditions.
    """
    return df[df['Weather Condition'] == 'Clear'].shape[0]

def filter_wind_speed_4kmh(df):
    """
    Filters records where 'Wind Speed_km/h' is exactly 4 km/h.
    """
    return df[df['Wind Speed_km/h'] == 4]

def check_null_values(df):
    """
    Returns the sum of null values per column.
    """
    return df.isnull().sum()

def calculate_mean_visibility(df):
    """
    Returns the mean of 'Visibility_km'.
    """
    return df['Visibility_km'].mean()

def calculate_std_pressure(df):
    """
    Returns the standard deviation of 'Press_kPa'.
    """
    return df['Press_kPa'].std()

def calculate_var_rel_hum(df):
    """
    Returns the variance of 'Rel Hum_%'.
    """
    return df['Rel Hum_%'].var()

def get_snow_instances(df):
    """
    Filters records where 'Weather Condition' contains 'Snow'.
    """
    return df[df['Weather Condition'].str.contains('Snow')]

def get_fog_instances(df):
    """
    Filters records where 'Weather Condition' is 'Fog'.
    """
    return df[df['Weather Condition'] == 'Fog']

def filter_wind_speed_visibility(df):
    """
    Filters records where 'Wind Speed_km/h' > 24 AND 'Visibility_km' == 25.
    """
    return df[(df['Wind Speed_km/h'] > 24) & (df['Visibility_km'] == 25)]

def get_grouped_mean_by_weather(df):
    """
    Returns the mean of numerical columns grouped by 'Weather Condition'.
    """
    return df.groupby('Weather Condition').mean(numeric_only=True)

def get_grouped_max_by_weather(df):
    """
    Returns the maximum of numerical columns grouped by 'Weather Condition'.
    """
    return df.groupby('Weather Condition').max()

def filter_clear_or_high_visibility(df):
    """
    Filters records where 'Weather Condition' is 'Clear' OR 'Visibility_km' > 40.
    """
    return df[(df['Weather Condition'] == 'Clear') | (df['Visibility_km'] > 40)]

def filter_clear_and_humid_or_high_visibility(df):
    """
    Filters records where ('Weather Condition' is 'Clear' AND 'Rel Hum_%' > 50) OR 'Visibility_km' > 40.
    """
    return df[((df['Weather Condition'] == 'Clear') & (df['Rel Hum_%'] > 50)) | (df['Visibility_km'] > 40)]

def main():
    file_path = 'file.csv' # Changed path for portability
    weather_data = load_data(file_path)

    print("\n--- Unique Wind Speed Values ---")
    print(get_unique_wind_speeds(weather_data))

    print("\n--- Count of Clear Weather Conditions ---")
    print(count_clear_weather(weather_data))

    print("\n--- Records with Wind Speed exactly 4 km/h ---")
    print(filter_wind_speed_4kmh(weather_data).head())

    print("\n--- Null Values per Column ---")
    print(check_null_values(weather_data))

    print("\n--- Mean Visibility (km) ---")
    print(calculate_mean_visibility(weather_data))

    print("\n--- Standard Deviation of Pressure (kPa) ---")
    print(calculate_std_pressure(weather_data))

    print("\n--- Variance of Relative Humidity (%) ---")
    print(calculate_var_rel_hum(weather_data))

    print("\n--- Records with Snow in Weather Condition ---")
    print(get_snow_instances(weather_data).head())

    print("\n--- Records with Fog Weather Condition ---")
    print(get_fog_instances(weather_data).head())

    print("\n--- Records with Wind Speed > 24 km/h AND Visibility == 25 km ---")
    print(filter_wind_speed_visibility(weather_data).head())

    print("\n--- Mean of Numerical Columns Grouped by Weather Condition ---")
    print(get_grouped_mean_by_weather(weather_data).head())

    print("\n--- Maximum of Numerical Columns Grouped by Weather Condition ---")
    print(get_grouped_max_by_weather(weather_data).head())

    print("\n--- Records with Clear Weather OR Visibility > 40 km ---")
    print(filter_clear_or_high_visibility(weather_data).head())

    print("\n--- Records with (Clear Weather AND Relative Humidity > 50) OR Visibility > 40 km ---")
    print(filter_clear_and_humid_or_high_visibility(weather_data).head())

if __name__ == '__main__':
    main()
# Out:
# --- Unique Wind Speed Values ---
# [ 4  7  6  9 15 13 20 22 19 24 30 35 39 32 33 26 44 43 48 37 28 17 11  0
#  83 70 57 46 41 52 50 63 54  2]
#
# --- Count of Clear Weather Conditions ---
# 1326
#
# --- Records with Wind Speed exactly 4 km/h ---
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 96   1/5/2012 0:00    -8.8             -11.7         79                4
# 101  1/5/2012 5:00    -7.0              -9.5         82                4
# 146  1/7/2012 2:00    -8.1             -11.1         79                4
#
#      Visibility_km  Press_kPa Weather Condition
# 0              8.0     101.24               Fog
# 1              8.0     101.24               Fog
# 96             9.7     100.32              Snow
# 101            4.0     100.19              Snow
# ...

# %% [markdown]
# ### Create `README.md`
#
# Create a file named `README.md` in the root of your project directory with the following content:
#
# ```markdown
# # Weather Data Analysis Project
#
# ## Project Description
#
# This project performs an exploratory data analysis on a weather dataset (`file.csv`). The analysis covers various aspects of the weather data, including wind speed, temperature, humidity, visibility, pressure, and weather conditions. The goal is to extract key insights and demonstrate common data manipulation and analysis techniques using the `pandas` library in Python.
#
# ## Dataset
#
# The dataset used in this project is `file.csv`, which contains hourly weather data, including:
# - `Date/Time`: Date and time of the observation
# - `Temp_C`: Temperature in Celsius
# - `Dew Point Temp_C`: Dew Point Temperature in Celsius
# - `Rel Hum_%`: Relative Humidity percentage
# - `Wind Speed_km/h`: Wind Speed in kilometers per hour
# - `Visibility_km`: Visibility in kilometers
# - `Press_kPa`: Pressure in kiloPascals
# - `Weather`: Describes the weather condition (e.g., Fog, Clear, Snow, Rain)
#
# ## Analysis Performed
#
# The `weather_analysis.py` script performs the following analyses:
#
# 1.  **Unique Wind Speed Values**: Identifies all unique wind speeds recorded in the dataset.
# 2.  **Count of Clear Weather**: Counts how many times the weather condition was 'Clear'.
# 3.  **Wind Speed at 4 km/h**: Filters and displays records where the wind speed was exactly 4 km/h.
# 4.  **Null Value Check**: Checks for and reports the sum of null values in each column.
# 5.  **Mean Visibility**: Calculates the average visibility across all records.
# 6.  **Standard Deviation of Pressure**: Computes the standard deviation of atmospheric pressure.
# 7.  **Variance of Relative Humidity**: Determines the variance of the relative humidity.
# 8.  **Snow Instances**: Retrieves all records where 'Snow' is present in the weather condition.
# 9.  **Fog Instances**: Filters and displays records where the weather condition is 'Fog'.
# 10. **High Wind and Specific Visibility**: Finds records where wind speed is greater than 24 km/h AND visibility is exactly 25 km.
# 11. **Mean by Weather Condition**: Calculates the mean of all numerical columns, grouped by each unique 'Weather Condition'.
# 12. **Maximum by Weather Condition**: Calculates the maximum of all numerical columns, grouped by each unique 'Weather Condition'.
# 13. **Clear Weather OR High Visibility**: Filters records where the 'Weather Condition' is 'Clear' OR 'Visibility_km' is greater than 40 km.
# 14. **Complex Filter**: Filters records where (('Weather Condition' is 'Clear' AND 'Rel Hum_%' is greater than 50) OR 'Visibility_km' is greater than 40).
#
# ## How to Run
#
# 1.  **Clone the repository**:
#     ```bash
#     git clone <repository-url>
#     cd <repository-name>
#     ```
# 2.  **Place the dataset**: Ensure `file.csv` is in the same directory as `weather_analysis.py`.
# 3.  **Install dependencies**: Install the required Python packages:
#     ```bash
#     pip install -r requirements.txt
#     ```
# 4.  **Run the analysis script**:
#     ```bash
#     python weather_analysis.py
#     ```
#
# The script will print the results of each analysis step to the console.
#
# ## Key Findings
#
# *(This section can be populated with specific insights derived from running the analysis, e.g., the most frequent weather conditions, average temperatures during clear days, etc.)*
# ```

# %% [markdown]
# ### Create `requirements.txt`
#
# Create a file named `requirements.txt` in the root of your project directory with the following content:
#
# ```
# pandas
# ```
#
# This file specifies the Python dependencies required for the project. In this case, `pandas` is the only library used for data manipulation and analysis.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Present the complete GitHub project code structure, including the main script, `README.md`, and `requirements.txt`, along with instructions on how to set up and run the project.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   **Comprehensive Data Analysis Script:** A Python script (`weather_analysis.py`) was successfully developed, integrating 15 distinct data processing and querying steps, including identifying unique wind speeds, counting 'Clear' weather instances, filtering data based on various conditions, checking for null values, renaming columns, calculating statistical measures (mean, standard deviation, variance), identifying specific weather events (Snow, Fog), and performing grouped aggregations (mean and maximum by 'Weather Condition').
# *   **Project Documentation:** A `README.md` file was created to provide a clear overview of the project, details about the `file.csv` dataset, a description of the analysis performed, and step-by-step instructions on how to set up and run the project.
# *   **Dependency Management:** A `requirements.txt` file was generated, accurately listing `pandas` as the sole Python library dependency, ensuring easy reproduction of the project environment.
# *   **Logical Correctness of Script:** Despite initial `FileNotFoundError` during execution due to the absence of the `file.csv` in the testing environment, the `weather_analysis.py` script was confirmed to be logically sound and correctly structured to perform all required analyses once the data file is present.
#
# ### Insights or Next Steps
#
# *   The established project structure and script provide a robust foundation for further weather data analysis, such as incorporating more complex time-series analysis or machine learning models for forecasting.
# *   To enhance user experience, consider adding a feature to download the `file.csv` automatically if it's not present, or provide clearer instructions within the script's `main` function for users to place the data file.
